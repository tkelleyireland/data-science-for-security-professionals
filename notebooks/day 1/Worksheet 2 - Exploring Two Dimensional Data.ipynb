# %% [markdown]
# <img src="../../img/logo_white_bkg_small.png" align="left" />
# # Worksheet 2:  Exploring Two Dimensional Data
# This worksheet covers concepts covered in the second half of Module 1 - Exploratory Data Analysis in Two Dimensions.  It should take no more than 20-30 minutes to complete.  Please raise your hand if you get stuck.
#
# There are many ways to accomplish the tasks that you are presented with, however you will find that by using the techniques covered in class, the exercises should be relatively simple.
#
# ## Import the Libraries
# For this exercise, we will be using:
# * Pandas (http://pandas.pydata.org/pandas-docs/stable/)
# * Numpy (https://docs.scipy.org/doc/numpy/reference/)
# * Matplotlib (http://matplotlib.org/api/pyplot_api.html)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Exercise 1: Reading various forms of JSON Data
# In the `/data/` folder, you will find a series of `.json` files called `dataN.json`, numbered 1-4.  Each file contains the following data:
#
#
# | |birthday	| first_name |last_name |
# |--|-----------|------------|----------|
# |0	|5\/3\/67	|Robert	|Hernandez |
# |1	|8\/4\/84	|Steve	|Smith |
# |2	|9\/13\/91	|Anne	|Raps |
# |3	|4\/15\/75	|Alice	|Muller |
#
# Using the `.read_json()` function and the various configuration options, read all these files into a dataframe.  The documentation is available here: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_json.html.

# %%
#Your code here...

# %% [markdown]
# ## Exercise 2:
# In the data file, there is a webserver file called `hackers-access.httpd`.  For this exercise, you will use this file to answer the following questions:
# 1.  Which browsers are the top 10 most used browsers in this data?
# 2.  Which are the top 10 most used operating systems?
#
# In order to accomplish this task, do the following:
# 1.  Write a function which takes a User Agent string as an argument and returns the relevant data.  HINT:  You might want to use python's `user_agents` module, the documentation for which is available here: (https://pypi.python.org/pypi/user-agents)
# 2.  Next, apply this function to the column which contains the user agent string.
# 3.  Store this series as a new column in the dataframe
# 4.  Count the occurances of each value in the new columns

# %%
import apache_log_parser
from user_agents import parse
#Read in the log file
line_parser = apache_log_parser.make_parser("%h %l %u %t \"%r\" %>s %b \"%{Referer}i\" \"%{User-agent}i\"")

server_log = open("../../data/hackers-access.httpd", "r")
parsed_server_data = []
for line in server_log:
    data = {}
    data = line_parser(line)
    parsed_server_data.append( data )

server_df = pd.DataFrame( parsed_server_data  )

# %%
#Write the functions
server_df
# Out:
#           remote_host remote_logname remote_user  \
# 0      195.154.46.135              -           -
# 1       23.95.237.180              -           -
# 2       23.95.237.180              -           -
# 3       158.222.5.157              -           -
# 4       158.222.5.157              -           -
# 5       158.222.5.157              -           -
# 6       158.222.5.157              -           -
# 7       158.222.5.157              -           -
# 8            5.39.5.5              -           -
# 9       180.180.64.16              -           -
# 10      180.180.64.16              -           -
# 11      180.180.64.16              -           -
# 12      180.180.64.16              -           -
# 13      180.180.64.16              -           -
# 14      180.180.64.16              -           -
# 15           5.39.5.5              -           -
# 16     222.88.236.235              -           -
# 17     222.88.236.235              -           -
# 18           5.39.5.5              -           -
# 19       89.42.237.71              -           -
# 20       89.42.237.71              -           -
# 21       89.42.237.71              -           -
# 22       89.42.237.71              -           -
# 23       89.42.237.71              -           -
# 24       89.42.237.71              -           -
# 25        200.55.25.2              -           -
# 26        200.55.25.2              -           -
# 27        200.55.25.2              -           -
# 28     211.196.252.10              -           -
# 29     211.196.252.10              -           -
# ...               ...            ...         ...
# 3426   199.195.159.11              -           -
# 3427   199.195.159.11              -           -
# 3428  180.180.115.137              -           -
# 3429  180.180.115.137              -           -
# 3430  180.180.115.137              -           -
# 3431  180.180.115.137              -           -
# 3432  180.180.115.137              -           -
# 3433  180.180.115.137              -           -
# 3434   23.254.164.173              -           -
# 3435   23.254.164.173              -           -
# 3436   23.254.164.173              -           -
# 3437   23.254.164.173              -           -
# 3438   23.254.164.173              -           -
# 3439   23.254.164.173              -           -
# 3440    89.32.251.246              -           -
# 3441    89.32.251.246              -           -
# 3442    89.32.251.246              -           -
# 3443    89.32.251.246              -           -
# 3444    89.32.251.246              -           -
# 3445   117.240.187.35              -           -
# 3446   117.240.187.35              -           -
# 3447   117.240.187.35              -           -
# 3448   117.240.187.35              -           -
# 3449   117.240.187.35              -           -
# 3450   117.240.187.35              -           -
# 3451    192.161.57.88              -           -
# 3452    192.161.57.88              -           -
# 3453    192.161.57.88              -           -
# 3454    192.161.57.88              -           -
# 3455    192.161.57.88              -           -
#
#                                      request_first_line  \
# 0     GET /linux/doing-pxe-without-dhcp-control HTTP...
# 1                               GET /join_form HTTP/1.0
# 2                              POST /join_form HTTP/1.1
# 3                               GET /join_form HTTP/1.0
# 4                              POST /join_form HTTP/1.1
# 5     GET /acl_users/credentials_cookie_auth/require...
# 6                              GET /login_form HTTP/1.1
# 7                             POST /login_form HTTP/1.1
# 8                               GET /join_form HTTP/1.1
# 9     GET /linux/doing-pxe-without-dhcp-control HTTP...
# 10                              GET /join_form HTTP/1.1
# 11                             POST /join_form HTTP/1.1
# 12    GET /acl_users/credentials_cookie_auth/require...
# 13                             GET /login_form HTTP/1.1
# 14                            POST /login_form HTTP/1.1
# 15                                       GET / HTTP/1.1
# 16    GET http://niels.basj.es/acl_users/credentials...
# 17    GET http://niels.basj.es/acl_users/credentials...
# 18                                       GET / HTTP/1.1
# 19                                       GET / HTTP/1.0
# 20                              GET /join_form HTTP/1.1
# 21                             POST /join_form HTTP/1.1
# 22    GET /acl_users/credentials_cookie_auth/require...
# 23                             GET /login_form HTTP/1.1
# 24                            POST /login_form HTTP/1.1
# 25    GET /acl_users/credentials_cookie_auth/require...
# 26                             GET /login_form HTTP/1.1
# 27                            POST /login_form HTTP/1.1
# 28    GET /acl_users/credentials_cookie_auth/require...
# 29                             GET /login_form HTTP/1.1
# ...                                                 ...
# 3426                           GET /login_form HTTP/1.1
# 3427                          POST /login_form HTTP/1.1
# 3428  GET /linux/doing-pxe-without-dhcp-control HTTP...
# 3429                            GET /join_form HTTP/1.1
# 3430                           POST /join_form HTTP/1.1
# 3431  GET /acl_users/credentials_cookie_auth/require...
# 3432                           GET /login_form HTTP/1.1
# 3433                          POST /login_form HTTP/1.1
# 3434  GET /linux/installing-my-new-server/voice-over...
# 3435                            GET /join_form HTTP/1.1
# 3436                           POST /join_form HTTP/1.1
# 3437  GET /acl_users/credentials_cookie_auth/require...
# 3438                           GET /login_form HTTP/1.1
# 3439                          POST /login_form HTTP/1.1
# 3440                            GET /join_form HTTP/1.0
# 3441                           POST /join_form HTTP/1.1
# 3442  GET /acl_users/credentials_cookie_auth/require...
# 3443                           GET /login_form HTTP/1.1
# 3444                          POST /login_form HTTP/1.1
# 3445                               GET /places HTTP/1.0
# 3446                            GET /join_form HTTP/1.1
# 3447                           POST /join_form HTTP/1.1
# 3448  GET /acl_users/credentials_cookie_auth/require...
# 3449                           GET /login_form HTTP/1.1
# 3450                          POST /login_form HTTP/1.1
# 3451                            GET /join_form HTTP/1.1
# 3452                           POST /join_form HTTP/1.1
# 3453  GET /acl_users/credentials_cookie_auth/require...
# 3454                           GET /login_form HTTP/1.1
# 3455                          POST /login_form HTTP/1.1
#
#                                  request_header_referer  \
# 0                               http://howto.basjes.nl/
# 1                               http://howto.basjes.nl/
# 2                      http://howto.basjes.nl/join_form
# 3                               http://howto.basjes.nl/
# 4                      http://howto.basjes.nl/join_form
# 5                      http://howto.basjes.nl/join_form
# 6                               http://howto.basjes.nl/
# 7                     http://howto.basjes.nl/login_form
# 8                               http://howto.basjes.nl/
# 9                               http://howto.basjes.nl/
# 10                              http://howto.basjes.nl/
# 11                     http://howto.basjes.nl/join_form
# 12                     http://howto.basjes.nl/join_form
# 13                              http://howto.basjes.nl/
# 14                    http://howto.basjes.nl/login_form
# 15                              http://howto.basjes.nl/
# 16                                http://niels.basj.es/
# 17                                http://niels.basj.es/
# 18                              http://howto.basjes.nl/
# 19                              http://niels.basjes.nl/
# 20                              http://niels.basjes.nl/
# 21                     http://niels.basjes.nl/join_form
# 22                     http://niels.basjes.nl/join_form
# 23                              http://niels.basjes.nl/
# 24                    http://niels.basjes.nl/login_form
# 25                              http://howto.basjes.nl/
# 26                              http://howto.basjes.nl/
# 27                    http://howto.basjes.nl/login_form
# 28                              http://howto.basjes.nl/
# 29                              http://howto.basjes.nl/
# ...                                                 ...
# 3426                            http://howto.basjes.nl/
# 3427                  http://howto.basjes.nl/login_form
# 3428                            http://howto.basjes.nl/
# 3429                            http://howto.basjes.nl/
# 3430                   http://howto.basjes.nl/join_form
# 3431                   http://howto.basjes.nl/join_form
# 3432                            http://howto.basjes.nl/
# 3433                  http://howto.basjes.nl/login_form
# 3434                            http://howto.basjes.nl/
# 3435  http://howto.basjes.nl/linux/installing-my-new...
# 3436                   http://howto.basjes.nl/join_form
# 3437                   http://howto.basjes.nl/join_form
# 3438                            http://howto.basjes.nl/
# 3439                  http://howto.basjes.nl/login_form
# 3440                            http://niels.basjes.nl/
# 3441                   http://niels.basjes.nl/join_form
# 3442                   http://niels.basjes.nl/join_form
# 3443                            http://niels.basjes.nl/
# 3444                  http://niels.basjes.nl/login_form
# 3445                            http://niels.basjes.nl/
# 3446                            http://niels.basjes.nl/
# 3447                   http://niels.basjes.nl/join_form
# 3448                   http://niels.basjes.nl/join_form
# 3449                            http://niels.basjes.nl/
# 3450                  http://niels.basjes.nl/login_form
# 3451                            http://niels.basjes.nl/
# 3452                   http://niels.basjes.nl/join_form
# 3453                   http://niels.basjes.nl/join_form
# 3454                            http://niels.basjes.nl/
# 3455                  http://niels.basjes.nl/login_form
#
#                               request_header_user_agent request_http_ver  \
# 0     Mozilla/5.0 (Windows NT 5.1; rv:35.0) Gecko/20...              1.1
# 1     Mozilla/5.0 (Windows NT 5.1; rv:35.0) Gecko/20...              1.0
# 2     Mozilla/5.0 (Windows NT 5.1; rv:35.0) Gecko/20...              1.1
# 3     Mozilla/5.0 (Windows NT 6.3; WOW64; rv:34.0) G...              1.0
# 4     Mozilla/5.0 (Windows NT 6.3; WOW64; rv:34.0) G...              1.1
# 5     Mozilla/5.0 (Windows NT 6.3; WOW64; rv:34.0) G...              1.1
# 6     Mozilla/5.0 (Windows NT 6.3; WOW64; rv:34.0) G...              1.1
# 7     Mozilla/5.0 (Windows NT 6.3; WOW64; rv:34.0) G...              1.1
# 8     Mozilla/5.0 (Windows NT 5.1; rv:34.0) Gecko/20...              1.1
# 9     Mozilla/5.0 (Windows NT 5.1; rv:35.0) Gecko/20...              1.1
# 10    Mozilla/5.0 (Windows NT 5.1; rv:35.0) Gecko/20...              1.1
# 11    Mozilla/5.0 (Windows NT 5.1; rv:35.0) Gecko/20...              1.1
# 12    Mozilla/5.0 (Windows NT 5.1; rv:35.0) Gecko/20...              1.1
# 13    Mozilla/5.0 (Windows NT 5.1; rv:35.0) Gecko/20...              1.1
# 14    Mozilla/5.0 (Windows NT 5.1; rv:35.0) Gecko/20...              1.1
# 15    Mozilla/5.0 (Windows NT 5.1; rv:34.0) Gecko/20...              1.1
# 16    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1...              1.0
# 17    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1...              1.1
# 18    Mozilla/5.0 (Windows NT 5.1; rv:34.0) Gecko/20...              1.1
# 19    Mozilla/5.0 (Windows NT 5.1; rv:34.0) Gecko/20...              1.0
# 20    Mozilla/5.0 (Windows NT 5.1; rv:34.0) Gecko/20...              1.1
# 21    Mozilla/5.0 (Windows NT 5.1; rv:34.0) Gecko/20...              1.1
# 22    Mozilla/5.0 (Windows NT 5.1; rv:34.0) Gecko/20...              1.1
# 23    Mozilla/5.0 (Windows NT 5.1; rv:34.0) Gecko/20...              1.1
# 24    Mozilla/5.0 (Windows NT 5.1; rv:34.0) Gecko/20...              1.1
# 25    Mozilla/5.0 (Windows NT 5.1; rv:35.0) Gecko/20...              1.0
# 26    Mozilla/5.0 (Windows NT 5.1; rv:35.0) Gecko/20...              1.1
# 27    Mozilla/5.0 (Windows NT 5.1; rv:35.0) Gecko/20...              1.1
# 28    Mozilla/5.0 (Windows NT 5.1; rv:35.0) Gecko/20...              1.0
# 29    Mozilla/5.0 (Windows NT 5.1; rv:35.0) Gecko/20...              1.1
# ...                                                 ...              ...
# 3426  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3427  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3428  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3429  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3430  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3431  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3432  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3433  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3434  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...              1.1
# 3435  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...              1.1
# 3436  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...              1.1
# 3437  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...              1.1
# 3438  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...              1.1
# 3439  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...              1.1
# 3440  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.0
# 3441  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3442  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3443  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3444  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3445  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.0
# 3446  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3447  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3448  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3449  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3450  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3451  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3452  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3453  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3454  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
# 3455  Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20...              1.1
#
#      request_method                                        request_url  \
# 0               GET              /linux/doing-pxe-without-dhcp-control
# 1               GET                                         /join_form
# 2              POST                                         /join_form
# 3               GET                                         /join_form
# 4              POST                                         /join_form
# 5               GET  /acl_users/credentials_cookie_auth/require_log...
# 6               GET                                        /login_form
# 7              POST                                        /login_form
# 8               GET                                         /join_form
# 9               GET              /linux/doing-pxe-without-dhcp-control
# 10              GET                                         /join_form
# 11             POST                                         /join_form
# 12              GET  /acl_users/credentials_cookie_auth/require_log...
# 13              GET                                        /login_form
# 14             POST                                        /login_form
# 15              GET                                                  /
# 16              GET  http://niels.basj.es/acl_users/credentials_coo...
# 17              GET  http://niels.basj.es/acl_users/credentials_coo...
# 18              GET                                                  /
# 19              GET                                                  /
# 20              GET                                         /join_form
# 21             POST                                         /join_form
# 22              GET  /acl_users/credentials_cookie_auth/require_log...
# 23              GET                                        /login_form
# 24             POST                                        /login_form
# 25              GET  /acl_users/credentials_cookie_auth/require_log...
# 26              GET                                        /login_form
# 27             POST                                        /login_form
# 28              GET  /acl_users/credentials_cookie_auth/require_log...
# 29              GET                                        /login_form
# ...             ...                                                ...
# 3426            GET                                        /login_form
# 3427           POST                                        /login_form
# 3428            GET              /linux/doing-pxe-without-dhcp-control
# 3429            GET                                         /join_form
# 3430           POST                                         /join_form
# 3431            GET  /acl_users/credentials_cookie_auth/require_log...
# 3432            GET                                        /login_form
# 3433           POST                                        /login_form
# 3434            GET  /linux/installing-my-new-server/voice-over-ip/...
# 3435            GET                                         /join_form
# 3436           POST                                         /join_form
# 3437            GET  /acl_users/credentials_cookie_auth/require_log...
# 3438            GET                                        /login_form
# 3439           POST                                        /login_form
# 3440            GET                                         /join_form
# 3441           POST                                         /join_form
# 3442            GET  /acl_users/credentials_cookie_auth/require_log...
# 3443            GET                                        /login_form
# 3444           POST                                        /login_form
# 3445            GET                                            /places
# 3446            GET                                         /join_form
# 3447           POST                                         /join_form
# 3448            GET  /acl_users/credentials_cookie_auth/require_log...
# 3449            GET                                        /login_form
# 3450           POST                                        /login_form
# 3451            GET                                         /join_form
# 3452           POST                                         /join_form
# 3453            GET  /acl_users/credentials_cookie_auth/require_log...
# 3454            GET                                        /login_form
# 3455           POST                                        /login_form
#
#      request_url_fragment             ...             request_url_username  \
# 0                                     ...                             None
# 1                                     ...                             None
# 2                                     ...                             None
# 3                                     ...                             None
# 4                                     ...                             None
# 5                                     ...                             None
# 6                                     ...                             None
# 7                                     ...                             None
# 8                                     ...                             None
# 9                                     ...                             None
# 10                                    ...                             None
# 11                                    ...                             None
# 12                                    ...                             None
# 13                                    ...                             None
# 14                                    ...                             None
# 15                                    ...                             None
# 16                                    ...                             None
# 17                                    ...                             None
# 18                                    ...                             None
# 19                                    ...                             None
# 20                                    ...                             None
# 21                                    ...                             None
# 22                                    ...                             None
# 23                                    ...                             None
# 24                                    ...                             None
# 25                                    ...                             None
# 26                                    ...                             None
# 27                                    ...                             None
# 28                                    ...                             None
# 29                                    ...                             None
# ...                   ...             ...                              ...
# 3426                                  ...                             None
# 3427                                  ...                             None
# 3428                                  ...                             None
# 3429                                  ...                             None
# 3430                                  ...                             None
# 3431                                  ...                             None
# 3432                                  ...                             None
# 3433                                  ...                             None
# 3434                                  ...                             None
# 3435                                  ...                             None
# 3436                                  ...                             None
# 3437                                  ...                             None
# 3438                                  ...                             None
# 3439                                  ...                             None
# 3440                                  ...                             None
# 3441                                  ...                             None
# 3442                                  ...                             None
# 3443                                  ...                             None
# 3444                                  ...                             None
# 3445                                  ...                             None
# 3446                                  ...                             None
# 3447                                  ...                             None
# 3448                                  ...                             None
# 3449                                  ...                             None
# 3450                                  ...                             None
# 3451                                  ...                             None
# 3452                                  ...                             None
# 3453                                  ...                             None
# 3454                                  ...                             None
# 3455                                  ...                             None
#
#      response_bytes_clf status                 time_received  \
# 0                 24323    200  [25/Oct/2015:04:11:25 +0100]
# 1                 11114    200  [25/Oct/2015:04:11:26 +0100]
# 2                  9093    302  [25/Oct/2015:04:11:27 +0100]
# 3                 11114    200  [25/Oct/2015:04:24:31 +0100]
# 4                  9093    302  [25/Oct/2015:04:24:32 +0100]
# 3435     2015-10-30 13:35:35+00:00   2015-10-30T13:35:35+00:00
# 3436     2015-10-30 13:35:36+00:00   2015-10-30T13:35:36+00:00
# 3437     2015-10-30 13:35:37+00:00   2015-10-30T13:35:37+00:00
# 3438     2015-10-30 13:35:38+00:00   2015-10-30T13:35:38+00:00
# 3439     2015-10-30 13:35:40+00:00   2015-10-30T13:35:40+00:00
# 3440     2015-10-30 13:41:24+00:00   2015-10-30T13:41:24+00:00
# 3441     2015-10-30 13:41:25+00:00   2015-10-30T13:41:25+00:00
# 3442     2015-10-30 13:41:26+00:00   2015-10-30T13:41:26+00:00
# 3443     2015-10-30 13:41:27+00:00   2015-10-30T13:41:27+00:00
# 3444     2015-10-30 13:41:28+00:00   2015-10-30T13:41:28+00:00
# 3445     2015-10-30 13:57:32+00:00   2015-10-30T13:57:32+00:00
# 3446     2015-10-30 13:57:39+00:00   2015-10-30T13:57:39+00:00
# 3447     2015-10-30 13:57:43+00:00   2015-10-30T13:57:43+00:00
# 3448     2015-10-30 13:57:47+00:00   2015-10-30T13:57:47+00:00
# 3449     2015-10-30 13:57:51+00:00   2015-10-30T13:57:51+00:00
# 3450     2015-10-30 13:57:54+00:00   2015-10-30T13:57:54+00:00
# 3451     2015-10-30 14:59:34+00:00   2015-10-30T14:59:34+00:00
# 3452     2015-10-30 14:59:35+00:00   2015-10-30T14:59:35+00:00
# 3453     2015-10-30 14:59:36+00:00   2015-10-30T14:59:36+00:00
# 3454     2015-10-30 14:59:38+00:00   2015-10-30T14:59:38+00:00
# 3455     2015-10-30 14:59:39+00:00   2015-10-30T14:59:39+00:00
#
# [3456 rows x 30 columns]

# %%
#Apply the functions to the dataframe

# %%
#Get the top 10 values

# %% [markdown]
# # Exercise 3:
# Using the `dailybots.csv` film, read the file into a DataFrame and perform the following operations:
# 1.  Filter the DataFrame to include bots from the Government/Politics Industry.
# 2.  Calculate the ratio of hosts to orgs and add this as a column to the DataFrame and output the result
# 3.  Calculate the total number of hosts infected by each BotFam in the Government/Politics Industry.  You should use the `groupby()` function which is documented here: (http://pandas.pydata.org/pandas-docs/stable/groupby.html)

# %%
#Your code here...
bots = pd.read_csv('../../data/dailybots.csv')

# %%
bots.head()
# Out:
#          date botfam             industry  hosts  orgs
# 0  2016-06-01  Bedep            Education     88    33
# 1  2016-06-01  Bedep              Finance    387    17
# 2  2016-06-01  Bedep  Government/Politics    430    42
# 3  2016-06-01  Bedep  Healthcare/Wellness     42    19
# 4  2016-06-01  Bedep        Manufacturing    184    18

# %%
bots['bots_ratio'] = bots['hosts'] / bots['orgs']

# %%
bots.head()
# Out:
#          date botfam             industry  hosts  orgs  bots_ratio
# 0  2016-06-01  Bedep            Education     88    33    2.666667
# 1  2016-06-01  Bedep              Finance    387    17   22.764706
# 2  2016-06-01  Bedep  Government/Politics    430    42   10.238095
# 3  2016-06-01  Bedep  Healthcare/Wellness     42    19    2.210526
# 4  2016-06-01  Bedep        Manufacturing    184    18   10.222222
